# %%
from sqlalchemy import create_engine, inspect
import creds
import pandas as pd

# %%
import os
count = 0
path = "images/"
dirs = os.listdir(path)
for i in dirs:
    count = count + 1
print(count)
# Out:
# 12669

# %%
host = creds.host
password = creds.password
port = creds.port
user = creds.user
database = creds.database
api_type = creds.api_type
engine = create_engine(f'postgresql+{api_type}://{user}:{password}@{host}:{port}/{database}')
# engine.connect()

# %%
df = pd.read_sql_table('products', engine)
df.drop(['create_time', 'page_id'], axis=1, inplace=True)

# %%
### Cleaning up the price column in the dataframe.
# Removes all rows which have "N/A" in the price column.
df = df[df['price'] != 'N/A']
# Removes all '£' from the price column
df['price'] = df['price'].str.strip('£')
# Changes all price values into floats/integers (numbers).
df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].astype('float64')

# %%
## This will check whether any row has been duplicated. The Sum will tell us how often it as been duplicated (0 = no duplicate, 1 = 1 duplicate, 2 = 2 duplicates etc.)
# df.duplicated().sum()
# Better version of this is to bring in multiple columns and check if there is a product that is the same over all columns.
# keep = false will make sure we keep looping and it wont stop after finding a duplicate.
duplicates = df.duplicated(subset=["product_name", "category", "product_description", "price", "location"], keep=False)
df[duplicates]
# we can also sort these out using df[duplicates].sort_values(by='columname')
# Out:
#                                         id  \
# 58    2e6db1e3-b60d-456a-8320-ddf4827e464f
# 71    a33f8af2-093e-40e3-b86c-477c3addb431
# 5268  eb60f24a-0171-4c29-b09a-2c8155809b3e
# 6084  76d84d36-bd2d-4cb2-a9c1-9b9c11ea1e52
#
#                                            product_name  \
# 58    February Sale offer Divan bed with mattress av...
# 71    February Sale offer Divan bed with mattress av...
# 5268     Mehndi | in Sparkhill, West Midlands | Gumtree
# 6084     Mehndi | in Sparkhill, West Midlands | Gumtree
#
#                                                category  \
# 58    Home & Garden / Beds & Bedroom Furniture / Sin...
# 71    Home & Garden / Beds & Bedroom Furniture / Sin...
# 5268                Health & Beauty / Tattoo & Body Art
# 6084                Health & Beauty / Tattoo & Body Art
#
#                                     product_description  price  \
# 58    💓Brand New All Beds 🛏️ Avaliable Here Please T...  130.0
# 71    💓Brand New All Beds 🛏️ Avaliable Here Please T...  130.0
# 5268  Each side- £5Both hands Upper side £9Both hand...    5.0
# 6084  Each side- £5Both hands Upper side £9Both hand...    5.0
#
#                       location
# 58     Nechells, West Midlands
# 71     Nechells, West Midlands
# 5268  Sparkhill, West Midlands
# 6084  Sparkhill, West Midlands

# %%
# This will remove all duplicates from the code
df.drop_duplicates(subset=["product_name", "category", "product_description", "price", "location"], keep=False)
# Out:
#                                         id  \
# 1     243809c0-9cfc-4486-ad12-3b7a16605ba9
# 2     1c58d3f9-8b93-47ea-9415-204fcc2a22e6
# 3     860673f1-57f6-47ba-8d2f-13f9e05b8f9a
# 4     59948726-29be-4b35-ade5-bb2fd7331856
# 5     16dbc860-696e-4cda-93f6-4dd4926573fb
# ...                                    ...
# 8085  c4148656-78a9-4f3e-b393-134fdc5ef900
# 8086  564e3411-768d-4250-a624-b119d696f103
# 8088  2b0a652b-46a2-4297-b619-5efeeb222787
# 8089  719fd40a-870e-4144-b324-55dff2e66fb4
# 8090  86d1806b-5575-4a7e-9160-f24f12be6c95
#
#                                            product_name  \
# 1     Mirror wall art | in Wokingham, Berkshire | Gu...
# 2     Stainless Steel Food Steamer | in Inverness, H...
# 3     Sun loungers | in Skegness, Lincolnshire | Gum...
# 4     Coffee side table from Ammunition ammo box hai...
# 5     Modern Shannon Sofa for sale at low cost | in ...
# ...                                                 ...
# 8085  Sony PlayStation VR Move Bundle | in Acocks Gr...
# 8086  Playstation VR V2 Bundle | in Acocks Green, We...
# 8088  Oculus quest 2 256gb | in Montrose, Angus | Gu...
# 8089  Logitech driving force shifter | in Carrickfer...
# 8090  20 GAMES & NINTENDO SWITCH BUNDLE | in Poole, ...
#
#                                                category  \
# 1     Home & Garden / Dining, Living Room Furniture ...
# 2                 Home & Garden / Other Household Goods
# 3     Home & Garden / Garden & Patio / Outdoor Setti...
# 4     Home & Garden / Dining, Living Room Furniture ...
# 5     Home & Garden / Dining, Living Room Furniture ...
# ...                                                 ...
# 8085  Video Games & Consoles / Consoles / PS4 (Sony ...
# 8086  Video Games & Consoles / Consoles / PS4 (Sony ...
# 8088  Video Games & Consoles / Other Video Games & C...
# 8089  Video Games & Consoles / Video Game Accessorie...
# 8090                     Video Games & Consoles / Games
#
#                                     product_description  price  \
# 1     Mirror wall art. Posted by Nisha in Dining, Li...    5.0
# 2     Morphy Richard’s (model no 48755)Stainless ste...   20.0
# 3     I have 2 of these - collection only as I don’t...   20.0
# 4     Great reclaimed army ammunition box used as co...  115.0
# 5     New Design Shannon Corner sofa  5 Seater Avail...  450.0
# ...                                                 ...    ...
# 8085  Sony PlayStation VR Move Bundle353CASH ON COLL...  260.0
# 8086  Playstation VR V2 Bundle355CASH ON COLLECTION ...  235.0
# 8088  Pick up only £250Comes with two pistols stocks...  250.0
# 8089  Bought at christmas from currys retailing at £...   30.0
# 8090  Nintendo Switch console only used 2/3 times. A...  450.0
#
#                           location
# 1             Wokingham, Berkshire
# 2              Inverness, Highland
# 3           Skegness, Lincolnshire
# 4               Radstock, Somerset
# 5                Delph, Manchester
# ...                            ...
# 8085   Acocks Green, West Midlands
# 8086   Acocks Green, West Midlands
# 8088               Montrose, Angus
# 8089  Carrickfergus, County Antrim
# 8090                 Poole, Dorset
#
# [7152 rows x 6 columns]

# %%
df['category'] = df['category'].astype('category')
df['1st_category'] = df['category'].str.split('/').apply(lambda x: x[0])
df['1st_category'] = df['1st_category'].astype('category')
df['encoded_category_1'] = df['1st_category'].cat.codes
df['2nd_category'] = df['category'].str.split('/').apply(lambda x: x[1])
df['2nd_category'] = df['2nd_category'].astype('category')
df['encoded_category_2'] = df['2nd_category'].cat.codes
df['3rd_category'] = df['category'].str.split('/').apply(lambda x: x[-1])
df['3rd_category'] = df['3rd_category'].astype('category')
df['encoded_category_3'] = df['3rd_category'].cat.codes
df.drop('category', axis=1, inplace=True)

# %%
df['location'] = df['location'].astype('category')
df['town'] = df['location'].str.split(',').apply(lambda x: x[0])
df['town'] = df['town'].astype('category')
df['town_encoded'] = df['town'].cat.codes
df['county'] = df['location'].str.split(',').apply(lambda x: x[-1])
df['county'] = df['county'].astype('category')
df['county_encoded'] = df['county'].cat.codes
df.drop('location', axis=1, inplace=True)

# %%
df.drop(['1st_category', '2nd_category', '3rd_category', 'town', 'county', 'id', 'product_description', 'product_name'], axis=1, inplace=True)

# %%
#To check if we have values above 10000
df[(df > 10000).any(1)]
# Out:
#            price  encoded_category_1  encoded_category_2  encoded_category_3  \
# 689      12345.0                   6                  73                 246
# 1534     12500.0                   2                  64                 203
# 1773     17659.0                   2                  64                 203
# 1977     12000.0                   9                  48                 152
# 2303     15000.0                   9                   0                   7
# 2678   1234567.0                  11                  42                  72
# 2899  10000000.0                  11                  10                  30
# 3475   1233333.0                   4                  13                 232
# 3624     20000.0                   0                  72                 227
# 3689     12345.0                   0                  35                 122
# 4012     12345.0                   0                  35                 122
# 4557     12345.0                   7                  68                 384
# 4749   1111111.0                   3                  18                  90
# 4827     11111.0                   3                  18                  90
# 5027     24700.0                   3                  18                 380
# 5145    399900.0                   3                  95                 264
# 6157    100000.0                   5                  43                 138
# 6717     18000.0                   8                  14                  48
# 6748     30000.0                   8                  86                 308
# 6764     12995.0                   8                  86                 308
# 6766     25000.0                   8                  86                 308
# 6808     22000.0                   8                  14                  48
# 6847     12995.0                   8                  86                 308
# 7031     60000.0                   8                  86                 308
# 7032     12000.0                   8                  14                  48
# 7033     12995.0                   8                  86                 308
# 7058     30000.0                   8                  14                  48
# 7062     23000.0                   8                  86                 308
# 7092     12345.0                   8                  14                  48
# 7217     23000.0                   8                  14                  48
# 7242     12995.0                   8                  86                 308
# 7264     17955.0                   8                  86                 308
# 7290     13995.0                   8                  86                 308
# 7378     45000.0                   8                  86                 308
# 7399    150000.0                   8                  14                  48
# 7582     12345.0                  12                  38                 125
#
#       town_encoded  county_encoded
# 689            736              53
# 1534           798              70
# 1773           503              53
# 1977            31              43
# 2303           808              53
# 2678           881              54
# 2899           901             113
# 3475           484             107
# 3624          1228              20
# 3689          1567              93
# 4012          1567              93
# 4557          1259              81
# 4749           887              92
# 4827           887              92
# 5027           147              53
# 5145          1493              53
# 6157           346              53
# 6717          1366              97
# 6748           872              73
# 6764           193              55
# 6766          1154              50
# 6808          1078              54
# 6847           193              55
# 7031          1539              54
# 7032           842              18
# 7033           193              55
# 7058          1259              81
# 7062           512              40
# 7092          1202              54
# 7217           264              28
# 7242           193              55
# 7264           193              55
# 7290           193              55
# 7378          1406               9
# 7399           850              51
# 7582           149              69

# %%
#There are values which exceeded 10000. I will drop them as they seem not to go with the common idea of facebook market.
# df.drop(df.loc[[2678,2899,3475,4749,5145,7399]].index, inplace=True)
df.drop(df[(df > 10000).any(1)].index, inplace=True)

# %%
#To check if we still have values above 10000.
df[(df > 10000).any(1)]
# Out:
# Empty DataFrame
# Columns: [price, encoded_category_1, encoded_category_2, encoded_category_3, town_encoded, county_encoded]
# Index: []

# %%
df
# Out:
#       price  encoded_category_1  encoded_category_2  encoded_category_3  \
# 1       5.0                   6                  22                 208
# 2      20.0                   6                  73                 246
# 3      20.0                   6                  39                 271
# 4     115.0                   6                  22                 225
# 5     450.0                   6                  22                 298
# ...     ...                 ...                 ...                 ...
# 8085  260.0                  12                  19                 277
# 8086  235.0                  12                  19                 277
# 8088  250.0                  12                  76                 267
# 8089   30.0                  12                 103                 266
# 8090  450.0                  12                  36                 123
#
#       town_encoded  county_encoded
# 1             1565               6
# 2              764              46
# 3             1282              52
# 4             1169              78
# 5              440              54
# ...            ...             ...
# 8085            10              93
# 8086            10              93
# 8088           989               2
# 8089           298              18
# 8090          1135              28
#
# [7120 rows x 6 columns]

# %%
df.to_csv('facebook_cleaned_tabular_data.csv', index=False)
